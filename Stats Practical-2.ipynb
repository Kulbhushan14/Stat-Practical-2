# %% [markdown]
# # Stats Practical-2

# %%
data=[23,24,32,45,12,43,67,45,32,56,32]

# %%
data
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data_copy=data.copy()

# %%
# importing the seaborn for veusalization 
import seaborn as sns
sns.histplot(data_copy,kde=True)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Count'>

# %%
data_copy.sort()

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67]

# %%
## added the element in to data copy

# %%
data_copy.append(179)

# %%
data_copy.append(210)

# %%
data_copy.append(290)

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 179, 210, 290]

# %%
#showing the data in plot format
sns.histplot(data_copy,kde=True)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Count'>

# %%
# This is a raw data
data
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
# this is a right shwed data
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 179, 210, 290]

# %%
# This is my left shewd ddata

data_copy2=data.copy()

# %%
data_copy2
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data_copy2.insert(0,-10)

# %%
data_copy2.insert(0,-75)

# %%
data_copy2.insert(0,-85)

# %%
data_copy2
# Out:
# [-85, -75, -10, 23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
sns.histplot(data_copy2,kde=True)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Count'>

# %%
# importing the pandas 

import pandas as pd

# %%
data2=pd.read_csv("iris.csv")

# %%
data2.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.histplot(data2["sepal_length"],kde=True)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(data2["sepal_width"],kde=True)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(data2["petal_length"],kde=True)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(data2['petal_width'],kde=True)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='petal_width', ylabel='Count'>

# %%
# importing the numpy 
import numpy as np

# %%
# Normal distribution
absulate=np.random.normal(0.5,0.2,1000)

# %%
absulate
# Out:
# array([ 0.38398721,  0.34378854,  0.30227637,  0.46438695,  0.3620475 ,
#         0.4269016 ,  0.16528323,  0.69136895,  0.11877777,  0.42573383,
#         0.11348507,  0.44283674,  0.09990253,  0.48492806,  0.53967658,
#         0.67202833,  0.2594711 ,  0.83726764,  0.78643599,  0.80450663,
#         0.68975516,  0.48687754,  0.32103499,  0.41922183,  0.10392119,
#         0.54319919,  0.41754219,  0.59148449,  0.17571577,  0.66311455,
#         0.19480117,  0.69991769,  0.52344536,  0.50702651,  0.21255484,
#         0.72758286,  0.00337789,  0.15480609,  0.35417675,  0.55072784,
#         0.71429133,  0.24804251,  0.66939538,  0.27870504,  0.33662768,
#         0.16430738,  0.28691281,  0.21347016,  0.49257559,  0.57774781,
#         0.43472113,  0.73280984,  0.70789475,  0.65167615,  0.78839215,
#         0.19403009,  0.81852265,  0.58818799,  0.59770138,  0.68040648,
#         0.66012132,  0.73445321,  0.33696979,  0.26758468,  0.64461087,
#         0.7723357 ,  0.50270813,  0.50700474,  0.55206157,  0.78300125,
#         0.63426519,  0.60980078,  0.34611523,  0.49623665,  0.57483698,
#         0.58797209,  0.49755239,  0.27555726,  0.90645663,  0.73356943,
#         0.2975091 ,  0.62007666,  0.28302149,  0.71886288,  0.32639484,
#         0.66645552,  0.59773979,  0.50800412,  0.28655167,  0.63367074,
#         0.56152913,  0.24586451,  0.30879187,  0.90732836,  0.62914093,
#         0.56784569,  0.73520576,  0.56567731,  0.64606011,  0.30430037,
#         0.51822379,  0.71937764,  0.27262805,  0.59438699,  0.49236627,
#         0.56229193,  0.54977881,  0.56683954,  0.3235817 ,  0.56829198,
#         0.28421187,  0.32503924,  0.74315459,  0.64958074,  0.46700418,
#         0.42279896,  0.40136776,  0.80075509,  0.49554351,  0.55860467,
#         0.91234618,  0.73972533,  0.36197879,  0.57164924,  0.75508538,
#         0.64994612,  0.11834662,  0.77003623,  0.52527906,  0.4061165 ,
#         0.66707752,  0.74703855,  0.63742087,  0.64408707,  0.53160557,
#         0.61855395,  0.30517402,  0.4519666 ,  0.5382142 ,  0.49558793,
#         0.42656329,  0.28592538,  0.38836548,  0.38259167,  0.58533332,
#         0.10539942,  0.50835624,  0.32004594,  0.64233825,  0.13043149,
#         0.79258626,  0.56471945,  0.44664444,  0.26678155,  0.48211962,
#         0.62847922,  0.58814551,  0.29485591,  0.46823683,  0.56000953,
#         0.51437333,  0.36866778,  0.66675315,  0.63380533,  0.33322435,
#         0.29817113,  0.72463643,  1.02892054,  0.24196116,  0.36565731,
#         0.42693352,  0.49600994,  0.66441336,  0.60367822,  0.43646332,
#         0.43961321,  0.30698699,  0.36011767,  0.23743109,  0.43640964,
#         0.44681927,  0.60444238,  0.26785099,  0.65011965,  0.385065  ,
#         0.47321579,  0.74353044,  0.7235609 ,  0.60182766,  0.45768037])

# %%
sns.histplot(absulate,kde=True)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Count'>

# %% [markdown]
# ### In probability theory, a log-normal (or lognormal) distribution is a continuous probability distribution of a random variable whose logarithm is normally distributed. Thus, if the random variable X is log-normally distributed, then Y = ln(X) has a normal distribution.Equivalently, if Y has a normal distribution, then the exponential function of Y, X = exp(Y), has a log-normal distribution.

# %%
mu=3.0
sigma=1.0
lognormal_distributed_data=np.random.lognormal(mu,sigma,1000)

# %%
sns.histplot(lognormal_distributed_data,kde=True)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Count'>

# %%
sns.histplot(np.log(lognormal_distributed_data),kde=True)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Count'>

# %%
import matplotlib.pyplot as plt
import scipy.stats as stat
import pylab

def plot_data(data):
    plt.figure(figsize=(10,6))
    plt.subplot(1,2,1)
    sns.histplot(data,kde=True)
    plt.subplot(1,2,2)
    stat.probplot(data,dist='norm',plot=pylab)
    plt.show()

# %%
plot_data(lognormal_distributed_data)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plot_data(np.log(lognormal_distributed_data))
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Why we use a qq plot
#
# ### To check my data is normal distributed or not

# %% [markdown]
# probability disrtribution function
# ----------------------------------
#
# probabilty mass function (Discrete Probability Distribution)
# - uniform
# - bernouli
# - binomial dist
# - possion
#
# prprobabilty density function(Continues Probability Distribution)
# - uniform
# - normal(SND)
# - lognormal
# - power law
# - pareto

# %%
from numpy import random
sns.distplot(random.uniform(size=500),hist=False)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7368\1012106223.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.uniform(size=500),hist=False)
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Density'>

# %%
sns.histplot(np.random.randint(1,8,size=800))
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Count'>

# %%
## Bernouli distribution 

p=0.3
sample_size=1000

bernouli_data=np.random.choice([0,1],size=sample_size,p=[1-p,p])

sns.histplot(bernouli_data,bins=2,kde=False,color="blue")
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Count'>

# %%
# Binomial Distribution 
no_of_trials=10
probaility=0.6

data3=np.random.binomial(no_of_trials,probaility,10000)

# %%
sns.distplot(data3)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7368\2956261776.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data3)
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Density'>

# %%
poisson_data = np.random.poisson(lam=5, size=1000)
 
# plotting a histogram
ax = sns.distplot(poisson_data,
                  kde=False,
                  color='blue')
ax.set(xlabel='Poisson Distribution', ylabel='Frequency')
 
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7368\2992645912.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(poisson_data,

# %% [markdown]
# # central limit theoram

# %%
population=np.random.randint(10,20,50)

# %%
population
# Out:
# array([19, 17, 15, 15, 16, 14, 11, 12, 10, 18, 15, 15, 10, 14, 11, 11, 14,
#        18, 10, 13, 16, 10, 15, 18, 11, 18, 14, 17, 11, 17, 13, 10, 13, 18,
#        18, 10, 14, 18, 12, 10, 19, 13, 18, 11, 15, 16, 18, 15, 14, 10])

# %%
np.mean(population)
# Out:
# 14.2

# %%
np.median(population)
# Out:
# 14.0

# %%
from statistics import mode
mode(population)
# Out:
# 18

# %%
## Random Ssample

sample=np.random.choice(population,20)

# %%
print(f"The mean of Random Sample: {np.mean(sample)}")
print(f"The median of Random Sample: {np.median(sample)}")
print(f"The mode of Random Sample: {mode(sample)}")
# Out:
# The mean of Random Sample: 14.0
# The median of Random Sample: 14.0
# The mode of Random Sample: 18

# %% [markdown]
# **Suppose you have a population with any shape of probability distribution (not necessarily normal), and you draw random samples of a fixed size from this population. As the sample size increases, the distribution of the sample means approaches a normal distribution, regardless of the shape of the original population distribution.**

# %%
sample1=np.random.choice(population,20)
sample2=np.random.choice(population,20)
sample3=np.random.choice(population,20)
sample4=np.random.choice(population,20)

# %%
print(sample1)
print(60*"=")
print(sample2)
print(60*"=")
print(sample3)
print(60*"=")
print(sample4)
# Out:
# [17 18 15 10 17 15 18 10 15 15 18 15 11 10 15 18 18 18 11 18]
# ============================================================
# [15 14 18 11 10 14 18 13 10 18 17 11 14 14 13 11 15 14 10 10]
# ============================================================
# [14 11 18 10 14 13 11 18 14 11 19 18 10 11 16 19 15 19 15 10]
# ============================================================
# [15 13 15 13 11 13 11 11 18 11 14 16 18 17 11 15 16 18 18 16]

# %%
mnean_of_the_sample=[]

all_sample=[sample1,sample2,sample3,sample4]

for sample in all_sample:
    print(np.mean(sample))
    mnean_of_the_sample.append(np.mean(sample))
# Out:
# 15.1
# 13.5
# 14.3
# 14.5

# %%
mnean_of_the_sample
# Out:
# [15.1, 13.5, 14.3, 14.5]

# %%
population=np.random.lognormal(3.0,1.0,1000)

# %%
population
# Out:
# array([  3.16401838, 228.71067178,  16.0384754 ,  25.18084623,
#         12.84778122,  19.98147367,  26.65781429,  15.41661177,
#          7.28602928,  34.72836522,  73.0614684 ,   9.97596516,
#         16.66920326,   5.69949376,  42.80053988,  24.23420736,
#         12.32247108,   1.84225547,  46.51310905,  40.55427413,
#         47.3677813 ,  22.79772087,  15.24496114, 133.56807757,
#         15.03407146,  10.09188814,  19.38910458,  33.92526397,
#         71.40460633,  12.44236474,   7.24468909,  36.36969226,
#          6.8243892 ,  68.59008654,   1.4418143 ,   8.85276647,
#         68.95211982,  86.94948978,   5.72486347,  34.16833499,
#          2.36541609,  20.69992122,  40.19717191,  33.40866754,
#         23.39831247,  33.98019154,  11.72679998,   9.26141608,
#         32.05276277,   4.27556282,  19.65239161,   2.45960381,
#         31.23598588,  13.43370504,  18.04957968,   1.75318544,
#        174.11175539,  14.3370254 ,  22.09955489,  15.31533396,
#         11.66546292,  60.5427806 ,  16.88634916,   2.49690118,
#         17.06550017,   6.12521808,   8.41135078,  45.12314208,
#         64.0062624 ,  13.72645125,  14.68057276,  11.34243506,
#        111.34229271,  42.61321012,  10.21227587,  97.63227912,
#          4.97078271,   5.99118198,  26.39081411, 129.51291663,
#         10.95310011,  17.49924167,   7.62330513,   8.19454231,
#         43.12660755,   9.71335572, 102.22383046,  28.87882764,
#          9.90437568,   3.09103358,  14.14624841,  31.61272402,
#         80.82708819,  11.42783328,   9.10111283,   9.25571498,
#         11.54562907,   4.79327071,  14.82584142,  47.4517818 ,
#          9.48414784,  25.27889248,  33.54362954,  56.99530439,
#          2.32156345,  29.04886049,  29.1649378 ,   7.10229787,
#         13.69324228,  29.10715199,  38.01273194,  90.91154686,
#         45.30002795,  16.32206174,  50.32721894,   8.61274602,
#         65.09921334,  42.16940884,   7.48414006,   7.73787287,
#          8.21329493,   7.76369639,  11.33828345,  94.03499439,
#          7.07968371,  32.6626545 ,  36.48763804,   1.98168527,
#         11.74156969,   6.03004431,  13.31886655,  22.33426234,
#          9.61544138,  79.08286766,  46.11086234,  15.95101388,
#         25.07567012, 117.22328216,  29.10350348,  14.09371209,
#         15.70784809,  12.40438009,  29.04926633,  90.07314577,
#         26.7963134 ,  46.10887311,  11.90424864,  17.87249486,
#         37.62374066,   9.81859491,  28.81854177,  46.83952623,
#         34.31172141,  10.74104992,   4.23281306,  11.42990664,
#         27.45186086,   3.36928476,   2.06700211,   8.22643671,
#         22.83949796,  34.9203035 ,  25.34520512, 343.72541856,
#         35.89534805,  19.52815344,   3.65524584,  24.42595066,
#         15.54534042,  28.18656331,  21.622679  ,  73.98063389,
#         24.79417734,   4.33352997,  12.23959903,  13.68002631,
#         73.5780922 ,  12.27402281,  21.96718271,   2.55311576,
#         20.73142166,  13.59005281,  16.29398386,   7.7693674 ,
#        130.28890647,   5.69486684,   2.21882158,  24.87908916,
#         48.51125285,  15.92827981,  44.77966973,  67.23802883,
#         27.38107604,  32.67573728,  11.95177574,   3.27091178,
#         22.81071258,  51.44212851,  45.30171035,   9.04382987,
#         24.89332817,  25.30893286,  10.01157125,   7.41245704])

# %%
len(population)
# Out:
# 1000

# %%
sns.distplot(population)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7368\2958836585.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(population)
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Density'>

# %% [markdown]
# Suppose you have a population with any shape of probability distribution (not necessarily normal), and you draw random samples**(at least 30)** of a fixed size(in our case i took 3000 initially) from this population. As the sample size increases**(it might be anything and take as much as data)**, the distribution of the sample means approaches a normal distribution, regardless of the shape of the original population distribution.

# %%
len(population)
# Out:
# 1000

# %%
size=int(len(population)*0.30)
print(size)
# Out:
# 300

# %%
sample_mean=[]

for i in range(1,31):
    sample=np.random.choice(population,size=size)
    sample_mean.append(np.mean(sample))

# %%
sample_mean
# Out:
# [33.933402843586066,
#  32.36199366890223,
#  35.60996142966223,
#  34.58430538860339,
#  33.51435469647911,
#  29.95606629138559,
#  33.8933505033848,
#  36.53989968424621,
#  30.867189139224084,
#  35.21714315483994,
#  31.321246435153057,
#  28.392468437146434,
#  30.17118350483687,
#  29.29053135938136,
#  29.44662038946851,
#  33.99998534475425,
#  32.126728856130306,
#  30.658432982980095,
#  32.18554010772135,
#  34.722904188035024,
#  34.02737067560636,
#  31.493605224980527,
#  34.269430235330205,
#  33.445881699520704,
#  29.221900966535873,
#  34.63115645908426,
#  27.936461564114847,
#  32.14293574116333,
#  32.888020046388625,
#  34.18876026183755]

# %%
sns.distplot(sample_mean)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7368\514007480.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sample_mean)
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Density'>
